# %%
import scipy.io as sio
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/mxqian/Projects/production_practice/data/data1/condition1.mat'
mat_file = sio.loadmat(path)

# %%
image = mat_file['source_img']
image1 = image[:, :, 2]
print(image1)
plt.savefig('/home/mxqian/Projects/production_practice/data/image/image1.jpg')
plt.imshow(image1)
plt.show()

print(mat_file['target1'])
# Out:
# [[ 1473.00543108  1202.14475002   729.04389443 ...,  1170.00683759
#    1415.51439413  1503.90990422]
#  [ 3213.70012534  1089.22664483  1860.50610961 ...,  2680.91604361
#     491.75862367   485.42073584]
#  [ 3029.57605059  1402.79330938  1711.29047304 ...,  4355.25974815
#     207.46433723  1072.5717163 ]
#  ...,
#  [  202.15082016  1316.36938764  2349.96216427 ...,  1778.22176735
#     191.79092865  1151.93928252]
#  [ 1300.75908881  1302.17547653   524.61757157 ...,  1924.43432738
#     905.21556146   790.84089192]
#  [  625.03214705  2893.5552264   2153.91238404 ...,   876.54963694
#    1788.56242228   662.2280769 ]]
# [[630  64 100  30]]
